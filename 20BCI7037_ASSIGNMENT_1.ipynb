# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4, 4)
columns = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4']
df = pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4
# 0  -0.120662  -0.708687   0.396684  -1.468615
# 1  -0.353584  -0.887047   0.033799  -1.039732
# 2  -0.540780   0.801261   2.469700  -0.220791
# 3  -0.721100   1.161432  -0.341454   0.242888

# %%
columns = ['Random Value ' + str(i+1) for i in range(4)]
df = pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0       -0.120662       -0.708687        0.396684       -1.468615
# 1       -0.353584       -0.887047        0.033799       -1.039732
# 2       -0.540780        0.801261        2.469700       -0.220791
# 3       -0.721100        1.161432       -0.341454        0.242888

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        -0.434031        0.091740        0.639682       -0.621563
# std          0.257213        1.040251        1.256680        0.774652
# min         -0.721100       -0.887047       -0.341454       -1.468615
# 25%         -0.585860       -0.753277       -0.060014       -1.146953
# 50%         -0.447182        0.046287        0.215241       -0.630262
# 75%         -0.295353        0.891304        0.914938       -0.104872
# max         -0.120662        1.161432        2.469700        0.242888

# %%
df.isna()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %%
df.loc[:,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0       -0.708687        0.396684
# 1       -0.887047        0.033799
# 2        0.801261        2.469700
# 3        1.161432       -0.341454

# %%
df.iloc[:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0       -0.708687        0.396684
# 1       -0.887047        0.033799
# 2        0.801261        2.469700
# 3        1.161432       -0.341454
